# %%
import pandas as pd
from pathlib import Path
import numpy as np
import math
import pickle 
path = Path('./')
train_path = path.joinpath('train.csv')
test_path = path.joinpath('test.csv')
submission_path = path.joinpath('submission_popular.csv')
metadata_path = path.joinpath('item_metadata.csv')

# %%
df_train = pd.read_csv(train_path)
df_test = pd.read_csv(test_path)
df_meta = pd.read_csv(metadata_path)
df_submission = pd.read_csv(submission_path)

# %%
action_list = set(df_train['action_type'].values)
reference_list = set(df_train['reference'].values)
platform_list = set(df_train['platform'].values)
city_list = set(df_train['city'].values)
device_list = set(df_train['device'].values)
filter_list = set(df_train['current_filters'].values)
filter_list =  [x for x in filter_list if str(x) != 'nan']

action_list = list(action_list)
action_list.sort()

reference_list = list(reference_list)
reference_list.sort()

platform_list = list(platform_list)
platform_list.sort()

city_list = list(city_list)
city_list.sort()

device_list = list(device_list)
device_list.sort()

filter_list = list(filter_list)
filter_list.sort()

# %%
#테스트 데이터에서 마지막 reference가 nan인지 확인
def check_data(data):
    max_error = 0
    datalength = len(data)
    for i in range(datalength):
        if(isinstance(data[i][-1,5], float)):
            if(math.isnan(data[i][-1,5]) == True):
                pass
            else:
                print('error')
                print(data[i])
                max_error +=1
        else:
            print('error')
            print(data[i])
            max_error +=1
        if(max_error > 10):
            break

# %%
#테스트 데이터에서 reference가 nan일때 그 전 action이 click out인지 확인
def check_data_alpha(data):
    max_error = 0
    datalength = len(data)
    for i in range(datalength):
        for j in range(len(data[i])):
            if(isinstance(data[i][j,5], float)):
                if(math.isnan(data[i][j,5]) == True):
                     if(data[i][j,4] != 'clickout item'):
                        print(data[i])
                        max_error +=1
        
        if(max_error > 10):
            break

# %%
#테스트 데이터에서 reference에 하나라도 nan이 있는지 판별 있다면 그 중 적어도 하나는 action이 click out인지 판별
def check_data_beta(data):
    max_error = 0
    datalength = len(data)
    for i in range(datalength):
        error_data_number = 0
        click_check = False
        for j in range(len(data[i])):
            if(isinstance(data[i][j,5], float) and math.isnan(data[i][j,5]) == True):
                error_data_number += 1
        if(error_data_number == 0):
            print(data[i])
            print('error')
            max_error +=1
        if(error_data_number != 0):
            for j in range(len(data[i])):
                if(isinstance(data[i][j,5], float) and math.isnan(data[i][j,5]) == True):
                    if(data[i][j,4] == 'clickout item'):
                        click_check = True
        if(click_check == False):
            print('error')
            print(data[i])
            max_error +=1
            #print(data[i])
            #print('datas')
        if(max_error > 10):
            break

# %%
def check_inference(data):
    datalength = len(data)
    maxlength = 0
    correct_data = 0
    new_data = []
    for i in range(datalength):
        if(data[i][-1,5] in data[i][-1,10].split('|')):
            new_data.append(data[i])
            correct_data += 1
        else:
            pass
            #print(i)
            #print('error')
            #maxlength +=1
    print(correct_data)
    return new_data

# %%
# 트레이닝 데이터를 세션 단위로 나눔
def make_data(data): 
    data_split = []
    temp_data = []
    train_size = len(data)
    action_index = 1
    for i in range(train_size):
        if(i==0):
            temp_data.append(data[i])
        if(i>0):
            if(data[i,action_index] == data[i-1,action_index]):
                temp_data.append(data[i])
            else:
                data_split.append(np.array(temp_data))
                temp_data = []
                temp_data.append(data[i])
    return data_split

# %%
train_data_split = make_data(df_train.values)

# %%
#트레이닝 데이터에서 click out이 존재하는 데이터만 뽑아냄
#트레이닝 데이터에서 끝부분이 click out이 되도록 뒷부분을 자름
def data_preprocess(data): 
    new_data = []
    for i in range(len(data)):
        check_data = False
        final_click = 0
        for j in range(len(data[i])):
            if(data[i][j,4] =='clickout item'):
                final_click = j
                check_data = True
        if(final_click < len(data[i])-1 and check_data):
            new_data.append(np.delete(data[i],np.s_[final_click+1:],0))
        elif(check_data):
            new_data.append(data[i])
    return new_data

# %%
train_data_preprocess = data_preprocess(train_data_split)

# %%
len(train_data_preprocess) #총 데이터 개수
# Out:
# 826874

# %%
train_data_preprocess = check_inference(train_data_preprocess)
# Out:
# 826537

# %%
train_data_preprocess = check_inference(train_data_preprocess)
# Out:
# 826537

# %%
def RepresentsInt(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False

# %%
#reference embedding 보조 함수
items = df_meta['item_id'].values
properties = df_meta['properties'].values
all_items_test = []
for i in range(len(properties)):
    p_data = properties[i].split('|')
    all_items_test += p_data
set_items = set(all_items_test)

list_items = list(set_items)
list_items.sort()
def embedding_item_diction():
    all_items = {}
    for i in range(len(properties)):
        all_items[items[i]] = properties[i].split('|')
    embedding_items = {}
    #print(len(list_items))
    for keys in all_items.keys():
        item_embeddings = [0]*len(list_items)
        for i in range(len(list_items)):
            if list_items[i] in all_items[keys]:
                item_embeddings[i] = 1
        embedding_items[keys] = item_embeddings
    return embedding_items
reference_diction = embedding_item_diction()

# %%
len(reference_diction)
# Out:
# 927142

# %%
len(reference_diction[1257342])
# Out:
# 157

# %%
#filter embedding 보조함수
all_filters = []
for i in range(len(filter_list)):
    if i>0:
        all_filters += filter_list[i].split('|')
all_filter_set = set(all_filters)
all_filter_list = list(all_filter_set)
all_filter_list.sort()
def filter_embedding(data, version):
    embedding_data = [0]*202
    if version == 1:
        datalist = data.split('|')
        for filters in datalist:
            embedding_data[all_filter_list.index(filters)] = 1
        return embedding_data

# %%
def one_hot_encoding(number, length):
    return [int(i==number) for i in range(length)]

# %%
def sum_list(list1, list2):
    length = len(list1)
    final_list = []
    for i in range(length):
        final_list.append(list1[i] +list2[i])
    return final_list

# %%
type(city_list)
# Out:
# list

# %%
# 전체 action embedding
def embedding(data, action_index):
    if action_index == 0: #user_id dim 0
        return []
    
    if action_index == 1: # session_id dim 0
        return []
    
    if action_index == 2: # timestep dim 0
        return []
    
    if action_index == 3: #step dim 1
        return []
    
    if action_index == 4: #action_type dim 10
        #print(one_hot_encoding(action_list.index(data), 10))
        return one_hot_encoding(action_list.index(data), 10)
    
    if action_index == 5: #reference dim 157
        if RepresentsInt(data):
            return reference_diction[int(data)]
        else:
            return [0]*157
        
    if action_index == 6: #platform dim 55
        return one_hot_encoding(platform_list.index(data), 55)
    
    if action_index == 7: #city dim 0
        #return city_list.index(data)
        return []
    
    if action_index == 8: #device dim 3
        return one_hot_encoding(device_list.index(data), 3)
    
    if action_index == 9: #current_filters dim 202
        if(isinstance(data, float) and math.isnan(data) == True):
            return [0]*202
        else:
            return filter_embedding(data, 1)
        
    if action_index == 10: #impressions dim 157
        if(isinstance(data, float) and math.isnan(data) == True):
            return [0]*157
        else:
            impression_embedding = [0]*157
            impression_list = data.split('|')
            for impression in impression_list:
                try:
                    impression_embedding =sum_list(impression_embedding, reference_diction[int(impression)])
                    
                except:
                    pass
                    #print(int(impression))
            '''
            if(len(impression_embedding) < 3925):
                impression_embedding += [0]*(3925-len(impression_embedding))   
            '''
            return impression_embedding
            
        
    if action_index == 11: #prices dim 25
        if(isinstance(data, float) and math.isnan(data) == True):
            return [0]*25
        else:
            price_embedding = []
            for prices in data.split('|'):
                price_embedding.append(int(prices))
            if(len(price_embedding) < 25):
                price_embedding += [0]*(25-len(price_embedding))   
            return price_embedding

# %%
def check_last_click(data):
    data_number = 0
    for i in range(len(data)):
        if(data[i][-1,4] == 'clickout item'):
            data_number +=1
    return data_number

# %%
action_type_length = 10
reference_length = 157
platform_length = 55
device_length = 3
current_filters_length = 202
impresssions_length = 3925
prices_length = 25
def addVector(vector1, vector2, coef, action_num):
    new_action_type = []
    new_reference = []
    new_platform = []
    new_device = []
    new_filters = []
    new_impressions = []
    new_prices = [] 
    #print(len(vector1))
    #print(len(vector2))
    for i in range(10):
        new_action_type.append(vector1[i] + np.power(coef,action_num)*vector2[i])
    
    for i in range(10, 167):
        new_action_type.append(vector1[i] + np.power(coef,action_num)*vector2[i])
        
    for i in range(167, 222):
        new_action_type.append(vector1[i])
    
    for i in range(222, 225):
        new_action_type.append(vector1[i])
        
    for i in range(225, 427):
        new_action_type.append(vector1[i] + np.power(coef,action_num)*vector2[i])
        
    return new_action_type

# %%
def MakeEmbeddingVector1(data):
    #embedding_vector = []
    #temp_vector = []
    session_vector = [0]*609 # session data embedding(length 10+157+55+3+202+157+25=609)
    item_vector = [] # item data embedding
    num_action = len(data)
    time_delay_coef = 0.1

    for i in range(num_action-1, -1, -1): #거꾸로
        timestep_vector = []
        for j in range(12):
            timestep_vector += embedding(data[i,j], j) 
        if(i == num_action-1):
            for idx in range(10, 167):
                timestep_vector[idx] = 0 # reference 부분을 0으로 만듦
        session_vector = addVector(session_vector, timestep_vector, time_delay_coef, num_action-1-i) #session vector 생성   
    item_vector.append(reference_diction[int(data[-1,5])])
    temp_impressions = data[-1, 10].split('|')
    for i in range(len(temp_impressions)):

        try:
            if(data[-1,5] != temp_impressions[i]):
                item_vector.append(reference_diction[int(temp_impressions[i])])
                #item_vector.append(int(temp_impressions[i]))
        except:
            #print('error')
            pass
    return session_vector, item_vector

# %%
def MakeEmbeddingVector2(data):
    #embedding_vector = []
    #temp_vector = []
    session_vector = [0]*609 # session data embedding(length 10+157+55+3+202+157+25=609)
    item_vector = [] # item data embedding
    num_action = len(data)
    time_delay_coef = 0.1
    correct_index = []
    for i in range(num_action-1, -1, -1): #거꾸로
        timestep_vector = []
        for j in range(12):
            timestep_vector += embedding(data[i,j], j) 
        if(i == num_action-1):
            for idx in range(10, 167):
                timestep_vector[idx] = 0 # reference 부분을 0으로 만듦
        session_vector = addVector(session_vector, timestep_vector, time_delay_coef, num_action-1-i) #session vector 생성   
    #item_vector.append(reference_diction[int(data[-1,5])])
    temp_impressions = data[-1, 10].split('|')
    for i in range(len(temp_impressions)):
        if(data[-1,5] == temp_impressions[i]):
            correct_index.append(i)
        item_vector.append(reference_diction[int(temp_impressions[i])])
    return session_vector, item_vector, correct_index

# %%
def MakeEmbeddingVector3(data):
    #embedding_vector = []
    #temp_vector = []
    #session_vector = [0]*609 # session data embedding(length 10+157+55+3+202+157+25=609)
    item_vector = [] # item data embedding
    num_action = len(data)
    #time_delay_coef = 0.1
    correct_index = []
    reference_vector = []
    filter_vector = [0]*202
    current_reference  = ''
    reference_size = 0
    for i in range(num_action-1, -1, -1): #거꾸로
        timestep_vector = []
        if i != num_action-1 and RepresentsInt(data[i, 5]) and current_reference != data[i,5] and reference_size < 2:
            reference_size += 1
            current_reference = data[1,5]       
            reference_vector += reference_diction[int(data[i, 5])]
        if(filter_vector == [0]*202):
            filter_vector = embedding(data[i,9], 9)
    reference_vector += [0]*(314-len(reference_vector))
    session_vector = embedding(data[-1, 4], 4) + reference_vector + embedding(data[-1, 6], 6) + embedding(data[-1, 8], 8) + filter_vector
    # 10+314+202+55+3 = 584
    '''
    for j in range(12):
        timestep_vector += embedding(data[i,j], j) 

    if(i == num_action-1):
        for idx in range(10, 167):
            timestep_vector[idx] = 0 # reference 부분을 0으로 만듦
    session_vector = addVector(session_vector, timestep_vector, time_delay_coef, num_action-1-i) #session vector 생성
    '''
    #item_vector.append(reference_diction[int(data[-1,5])])
    temp_impressions = data[-1, 10].split('|')
    for i in range(len(temp_impressions)):
        if(data[-1,5] == temp_impressions[i]):
            correct_index.append(i)
        item_vector.append(reference_diction[int(temp_impressions[i])])
    return session_vector, item_vector, correct_index

# %%
x = [0,0,0]
x[0:3] =[1,1,1]
x + [0]*(3-3)
# Out:
# [1, 1, 1]

# %%
sevec, itemvec, crindex = MakeEmbeddingVector3(train_data_preprocess[0])

# %%
len(itemvec)
# Out:
# 25

# %%
del df_train
del df_test
del df_meta
del df_submission
del train_data_split

final_train_data = []
final_train_label = []
datalength = len(train_data_preprocess)

num_error = 0
for i in range(datalength):
    if(i%10000 ==0):
        print('making data....', i)
    try:
        temp_train, temp_label = MakeEmbeddingVector(train_data_preprocess[i])
    except:
        num_error += 1
    '''    
    if(num_error>10):
        break
    '''
    final_train_data.append(temp_train)
    final_train_label.append(temp_label)
    
#final_train_data = np.asarray(final_train_data)
#final_train_label = np.asarray(final_train_label)
print('number of error is : ', num_error)
print('total data is : ', len(final_train_data))
with open('final_train_data.pickle', 'wb') as f:
    pickle.dump(final_train_data, f, pickle.HIGHEST_PROTOCOL)
    
with open('final_train_label.pickle', 'wb') as f:
    pickle.dump(final_train_label, f, pickle.HIGHEST_PROTOCOL)
# Out:
# making data.... 0
# 5814172
# 8964532
# 8611078
# 5814172
# 5786780
# 4466176
# 4466176
# 4466176
# 4466176
# 4466176
# 8576928
# 8220214
# 8220214
# 8724058
# 8994580
# 8994580
# 8994580
# 9761132
# 9761132
# 9761132
# 8645590
# 8645590
# 1308066
# 1308066
# 1308066
# 1308066
# 11103906
# 8980878
# 5777082
# 7176596
# 8978614
# 8978614
# 8978614
# 8978614
# 10364188
# 10855548
# 10855548
# 5750368
# 5405700
# 5405700
# 5405700
# 5405700
# 6448102
# 8985756
# 2269860
# 7309646
# 7122966
# 7122966
# 7122966
# 7122966
# 7122966
# 7346452
# 4650392
# 4650392
# 4650392
# 4650392
# 8183586
# 8598328
# 8183586
# 7309652
# 9520364

# %%
len(train_data_preprocess)
# Out:
# 826537

# %%
import numpy as np
import tensorflow as tf
data_num = 826874
train_embedding_dim= 584
item_embedding_dim = 157
latent_dim = 200
learning_rate = 1e-3
session_data = np.zeros((data_num,train_embedding_dim))
#positive_label = np.zeros((data_num, item_embedding_dim))
#negative_labels = np.zeros((data_num, item_embedding_dim))
#negative_number = np.zeros((data_num, 1))
item = np.zeros((3,4)) # 임시

# %%
tf.reset_default_graph()
session_feature = tf.get_variable("session_feature", [train_embedding_dim, latent_dim], initializer=tf.random_normal_initializer())
item_feature = tf.get_variable("item_feature", [item_embedding_dim, latent_dim], initializer=tf.random_normal_initializer())
session_bias = tf.get_variable("session_bias", [train_embedding_dim], initializer=tf.random_normal_initializer())
item_bias = tf.get_variable("item_bias", [item_embedding_dim], initializer=tf.random_normal_initializer())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
train_data = tf.placeholder(tf.float32, shape=(train_embedding_dim))
train_items  = tf.placeholder(tf.float32, shape=(None, item_embedding_dim))
train_index = tf.placeholder(tf.int32, [1])

# %%
train_index[0]
# Out:
# <tf.Tensor 'strided_slice:0' shape=() dtype=int32>

# %%
print(tf.matmul(tf.matmul(train_items, item_feature), tf.transpose(tf.matmul(tf.expand_dims(train_data,0), session_feature))))
#x =  tf.matmul(tf.matmul(train_items, item_feature), tf.transpose(tf.matmul(tf.expand_dims(train_data,0), session_feature)))
print(tf.matmul(tf.expand_dims(train_data,0), tf.expand_dims(session_bias,1)))
print(tf.matmul(train_items, tf.expand_dims(item_bias,1)))

scores = tf.matmul(tf.matmul(train_items, item_feature), tf.transpose(tf.matmul(tf.expand_dims(train_data,0), session_feature))) +  \
tf.matmul(tf.expand_dims(train_data,0), tf.expand_dims(session_bias,1)) +\
tf.matmul(train_items, tf.expand_dims(item_bias,1))
#print(positive_score)
# Out:
# Tensor("MatMul_2:0", shape=(?, 1), dtype=float32)
# Tensor("MatMul_3:0", shape=(1, 1), dtype=float32)
# Tensor("MatMul_4:0", shape=(?, 1), dtype=float32)

# %%
loss = -tf.reduce_mean(tf.math.log(tf.sigmoid(scores[train_index[0]] - scores)), 0)

# %%
loss2 = tf.reduce_mean(tf.sigmoid(scores- scores[train_index[0]]) + tf.sigmoid(tf.math.pow(scores,2)))

# %%
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss2)

# %%
scores
# Out:
# <tf.Tensor 'add_1:0' shape=(?, 1) dtype=float32>

# %%
accuracy = tf.cast(tf.argmax(scores)[0] == train_index[0], tf.float32)

# %%
accuracy
# Out:
# <tf.Tensor 'Cast:0' shape=() dtype=float32>

# %%
batch_data, batch_items, correct_index = MakeEmbeddingVector3(train_data_preprocess[2])
batch_data  = np.asarray(batch_data)
batch_items = np.asarray(batch_items)

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())
sc = sess.run(scores, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})
sc = sess.run(scores, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})
#_loss = sess.run(scores, feed_dict = {train_data : batch_data, train_items : batch_items})
#te = sess.run(temp_value, feed_dict = {train_data : batch_data, train_items : batch_items})

# %%
sess.close()

# %%
sc = sess.run(scores, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})

# %%
sc
# Out:
# array([[  -1.3825867],
#        [-166.73303  ],
#        [  21.948414 ],
#        [ -51.466507 ],
#        [   1.6711503],
#        [ -79.502205 ],
#        [ -44.891983 ],
#        [ -59.786026 ],
#        [  18.005013 ],
#        [  -9.265203 ],
#        [ -86.04162  ],
#        [  15.62155  ],
#        [-150.52332  ],
#        [ -20.207943 ],
#        [-121.30979  ],
#        [ -73.53308  ],
#        [-175.25984  ],
#        [  53.116966 ],
#        [ -76.79295  ],
#        [  35.82706  ],
#        [  45.186028 ],
#        [ -90.31851  ],
#        [   1.1448324],
#        [ -62.64221  ],
#        [  39.84408  ]], dtype=float32)

# %%
np.shape(sc)[0]
# Out:
# 25

# %%
np.argmax(sc, axis = 0)[0]
# Out:
# 17

# %%
list(np.squeeze(np.argsort(sc, axis = 0))).index(17)
# Out:
# 24

# %%
sess.run(accuracy, feed_dict = {train_data : batch_data, train_items : batch_items})
# Out:
# 0.0

# %%
sess.run(optimizer, feed_dict = {train_data : batch_data, train_items : batch_items})

# %%
def get_MRS(score, idx):
    return (list(np.squeeze(np.argsort(score, axis = 0))).index(idx)+1)/np.shape(score)[0]

# %%
 get_MRS(sc, 17)
# Out:
# 1.0

# %%
scores[3]
# Out:
# <tf.Tensor 'strided_slice_7:0' shape=(1,) dtype=float32>

# %%
batch_data, batch_items, correct_index = MakeEmbeddingVector3(train_data_preprocess[7])

# %%
len(batch_items)
# Out:
# 25

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
all_data_number = len(session_data)
with tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())
    step = 0
    mean_loss = 0
    mean_rs = 0
    data_number = 0
    for i in range(all_data_number):
        #print(i)
        #if i>100:
        #    break
        
        try:
            batch_data, batch_items, correct_index = MakeEmbeddingVector3(train_data_preprocess[i])
            batch_data  = np.asarray(batch_data)
            batch_items = np.asarray(batch_items)

            sess.run(optimizer, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})
            ls = sess.run(loss2, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})
            _score = sess.run(scores, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})
            current_rs = get_MRS(_score, correct_index[0])
            
            #print(np.argmax(_score, axis = 0)[0])
            #print(correct_index[0])
            
            mean_rs += current_rs 
            mean_loss += ls
            data_number +=1
            if (step % 500 == 1):
                #data_index = sess.run(tf.argmax(scores)[0], feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})

                #acc = sess.run(accuracy, feed_dict = {train_data : batch_data, train_items : batch_items, train_index : correct_index})
                print('step', step )
                print("output index is : ", np.argmax(_score, axis = 0)[0])
                print("correct index is : ", correct_index[0])
                print("corrent rs is : ", current_rs)
                print("mean loss is : ", mean_loss / data_number)
                print("mean reciprocal score is : ", mean_rs / data_number)
                print("data num is : ", data_number)
                mean_rs =0
                mean_loss = 0
                data_number = 0
            step +=1
                
        except:
            pass
# Out:
# step 1
# output index is :  17
# correct index is :  0
# corrent rs is :  0.48
# mean loss is :  1.659999966621399
# mean reciprocal score is :  0.36
# data num is :  2
# step 501
# output index is :  6
# correct index is :  6
# corrent rs is :  1.0
# mean loss is :  1.472057652235031
# mean reciprocal score is :  0.5505141976022507
# data num is :  500
# step 1001
# output index is :  14
# correct index is :  1
# corrent rs is :  0.32
# mean loss is :  1.4832957093715669
# mean reciprocal score is :  0.5391933081924583
# data num is :  500
# step 1501
# output index is :  15
# correct index is :  1
# corrent rs is :  0.28
# mean loss is :  1.4639697771072389
# mean reciprocal score is :  0.560957670529766
# data num is :  500
# step 2001
# output index is :  23
# correct index is :  1
# corrent rs is :  0.08333333333333333
# mean loss is :  1.4624988219738007
# mean reciprocal score is :  0.562224698689758
# data num is :  500
# step 2501
# output index is :  10
# correct index is :  0
# corrent rs is :  0.0625
# mean loss is :  1.4349466745853423
# mean reciprocal score is :  0.5878759951097944
# data num is :  500
# step 3001
# output index is :  0
# correct index is :  5
# corrent rs is :  0.36
# mean loss is :  1.4387443969249725
# mean reciprocal score is :  0.5849934029652462
# data num is :  500
# step 3501
# output index is :  10
# correct index is :  11
# corrent rs is :  0.92
# mean loss is :  1.4495329470634462
# mean reciprocal score is :  0.5745618815275602
# data num is :  500
# step 4001
# output index is :  20
# correct index is :  0
# corrent rs is :  0.16
# mean loss is :  1.4541558414697646
# mean reciprocal score is :  0.5688662134617599
# data num is :  500
# step 4501
# output index is :  16
# correct index is :  0
# corrent rs is :  0.36
# mean loss is :  1.4226728310585022
# mean reciprocal score is :  0.602018564967361
# data num is :  500
# step 5001
# output index is :  13
# correct index is :  1
# corrent rs is :  0.35
# mean loss is :  1.422505793452263
# mean reciprocal score is :  0.6035635559489203
# data num is :  500
# step 5501
# output index is :  18
# correct index is :  5
# corrent rs is :  0.6
# mean loss is :  1.411672877907753
# mean reciprocal score is :  0.6137335454955001
# data num is :  500
# step 6001
# output index is :  2
# correct index is :  1
# corrent rs is :  0.64
# mean loss is :  1.4097529879808426
# mean reciprocal score is :  0.614458102586156
# data num is :  500
# step 6501
# output index is :  7
# correct index is :  17
# corrent rs is :  0.92
# mean loss is :  1.421951708316803
# mean reciprocal score is :  0.6031101677041493
# data num is :  500
# step 7001
# output index is :  20
# correct index is :  0
# corrent rs is :  0.88
# mean loss is :  1.4047142279148102
# mean reciprocal score is :  0.6199310753825672
# data num is :  500
# step 7501
# output index is :  6
# correct index is :  11
# corrent rs is :  0.76
# mean loss is :  1.4336013059616088
# mean reciprocal score is :  0.5910929350235029
# data num is :  500
# step 8001
# output index is :  2
# correct index is :  0
# corrent rs is :  0.4
# mean loss is :  1.422552156686783
# mean reciprocal score is :  0.6006059825478359
# data num is :  500
# step 8501
# output index is :  18
# correct index is :  5
# corrent rs is :  0.92
# mean loss is :  1.4197888915538788
# mean reciprocal score is :  0.605049569239931
# data num is :  500
# step 9001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.4069660050868988
# mean reciprocal score is :  0.6197067429372198
# data num is :  500
# step 9501
# output index is :  3
# correct index is :  1
# corrent rs is :  0.8571428571428571
# mean loss is :  1.4270291223526002
# mean reciprocal score is :  0.5975486490334722
# data num is :  500
# step 10001
# output index is :  10
# correct index is :  6
# corrent rs is :  0.8
# mean loss is :  1.4460961282253266
# mean reciprocal score is :  0.578769231396324
# data num is :  500
# step 10501
# output index is :  22
# correct index is :  4
# corrent rs is :  0.4
# mean loss is :  1.425797385454178
# mean reciprocal score is :  0.5981314885082761
# data num is :  500
# step 11001
# output index is :  0
# correct index is :  3
# corrent rs is :  0.6
# mean loss is :  1.4238495218753815
# mean reciprocal score is :  0.6001748266747239
# data num is :  500
# step 11501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.125
# mean loss is :  1.4165145056247712
# mean reciprocal score is :  0.6078877531586581
# data num is :  500
# step 12001
# output index is :  16
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.4105570697784424
# mean reciprocal score is :  0.6131426045951172
# data num is :  500
# step 12501
# output index is :  6
# correct index is :  0
# corrent rs is :  0.6666666666666666
# mean loss is :  1.397083951473236
# mean reciprocal score is :  0.627765988136316
# data num is :  500
# step 13001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.4011388149261474
# mean reciprocal score is :  0.6228305970039891
# data num is :  500
# step 13501
# output index is :  3
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.4115440254211427
# mean reciprocal score is :  0.612735491303614
# data num is :  500
# step 14001
# output index is :  23
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.4081936419010161
# mean reciprocal score is :  0.6169887638292365
# data num is :  500
# step 14501
# output index is :  0
# correct index is :  9
# corrent rs is :  0.28
# mean loss is :  1.383710897922516
# mean reciprocal score is :  0.6415271664656967
# data num is :  500
# step 15001
# output index is :  9
# correct index is :  2
# corrent rs is :  0.6
# mean loss is :  1.364820903778076
# mean reciprocal score is :  0.6598566203224396
# data num is :  500
# step 15501
# output index is :  6
# correct index is :  12
# corrent rs is :  0.76
# mean loss is :  1.3733464953899384
# mean reciprocal score is :  0.650437896636499
# data num is :  500
# step 16001
# output index is :  1
# correct index is :  18
# corrent rs is :  0.52
# mean loss is :  1.3884555056095123
# mean reciprocal score is :  0.6367135396592898
# data num is :  500
# step 16501
# output index is :  9
# correct index is :  10
# corrent rs is :  0.76
# mean loss is :  1.3964491245746613
# mean reciprocal score is :  0.6289306805838308
# data num is :  500
# step 17001
# output index is :  14
# correct index is :  0
# corrent rs is :  0.44
# mean loss is :  1.416790219783783
# mean reciprocal score is :  0.6080204348368464
# data num is :  500
# step 17501
# output index is :  17
# correct index is :  1
# corrent rs is :  0.84
# mean loss is :  1.3930158672332764
# mean reciprocal score is :  0.6326695783613945
# data num is :  500
# step 18001
# output index is :  3
# correct index is :  0
# corrent rs is :  0.8571428571428571
# mean loss is :  1.3677203495502472
# mean reciprocal score is :  0.6565312266690395
# data num is :  500
# step 18501
# output index is :  14
# correct index is :  0
# corrent rs is :  0.36
# mean loss is :  1.3850784163475036
# mean reciprocal score is :  0.6391117545909617
# data num is :  500
# step 19001
# output index is :  10
# correct index is :  8
# corrent rs is :  0.35294117647058826
# mean loss is :  1.3765273677110672
# mean reciprocal score is :  0.6478674665727776
# data num is :  500
# step 19501
# output index is :  4
# correct index is :  0
# corrent rs is :  0.48
# mean loss is :  1.3794571800231934
# mean reciprocal score is :  0.6473988321473475
# data num is :  500
# step 20001
# output index is :  13
# correct index is :  13
# corrent rs is :  1.0
# mean loss is :  1.3972672251462936
# mean reciprocal score is :  0.6284545253543955
# data num is :  500
# step 20501
# output index is :  16
# correct index is :  0
# corrent rs is :  0.76
# mean loss is :  1.3886269786357879
# mean reciprocal score is :  0.6358556874645231
# data num is :  500
# step 21001
# output index is :  2
# correct index is :  2
# corrent rs is :  1.0
# mean loss is :  1.3909900062084197
# mean reciprocal score is :  0.6317168255569227
# data num is :  500
# step 21501
# output index is :  15
# correct index is :  0
# corrent rs is :  0.48
# mean loss is :  1.3417052283287048
# mean reciprocal score is :  0.682258183853507
# data num is :  500
# step 22001
# output index is :  5
# correct index is :  9
# corrent rs is :  0.72
# mean loss is :  1.387130611896515
# mean reciprocal score is :  0.6367105750244285
# data num is :  500
# step 22501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.392787896156311
# mean reciprocal score is :  0.6304627362105593
# data num is :  500
# step 23001
# output index is :  22
# correct index is :  1
# corrent rs is :  0.6
# mean loss is :  1.3545563082695007
# mean reciprocal score is :  0.6725961980986511
# data num is :  500
# step 23501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.76
# mean loss is :  1.3867230656147003
# mean reciprocal score is :  0.6376426406379555
# data num is :  500
# step 24001
# output index is :  9
# correct index is :  0
# corrent rs is :  0.68
# mean loss is :  1.371281874895096
# mean reciprocal score is :  0.6529949419643032
# data num is :  500
# step 24501
# output index is :  0
# correct index is :  1
# corrent rs is :  0.88
# mean loss is :  1.3929586992263794
# mean reciprocal score is :  0.6311003742429476
# data num is :  500
# step 25001
# output index is :  17
# correct index is :  5
# corrent rs is :  0.3333333333333333
# mean loss is :  1.3614093055725098
# mean reciprocal score is :  0.664233651187657
# data num is :  500
# step 25501
# output index is :  3
# correct index is :  3
# corrent rs is :  1.0
# mean loss is :  1.3775126653909684
# mean reciprocal score is :  0.6463969924509466
# data num is :  500
# step 26001
# output index is :  13
# correct index is :  6
# corrent rs is :  0.55
# mean loss is :  1.3629391527175903
# mean reciprocal score is :  0.6604359438565504
# data num is :  500
# step 26501
# output index is :  12
# correct index is :  0
# corrent rs is :  0.36
# mean loss is :  1.3602321660518646
# mean reciprocal score is :  0.6636651434714156
# data num is :  500
# step 27001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3727776625156403
# mean reciprocal score is :  0.6523430671646594
# data num is :  500
# step 27501
# output index is :  4
# correct index is :  1
# corrent rs is :  0.96
# mean loss is :  1.404479882478714
# mean reciprocal score is :  0.6189901490268758
# data num is :  500
# step 28001
# output index is :  3
# correct index is :  0
# corrent rs is :  0.12
# mean loss is :  1.4127651541233062
# mean reciprocal score is :  0.6115532512803599
# data num is :  500
# step 28501
# output index is :  3
# correct index is :  0
# corrent rs is :  0.32
# mean loss is :  1.4217443144321442
# mean reciprocal score is :  0.6023191769658526
# data num is :  500
# step 29001
# output index is :  12
# correct index is :  4
# corrent rs is :  0.24
# mean loss is :  1.4595928249359131
# mean reciprocal score is :  0.5651270515882767
# data num is :  500
# step 29501
# output index is :  8
# correct index is :  1
# corrent rs is :  0.7391304347826086
# mean loss is :  1.4370911839008331
# mean reciprocal score is :  0.5885378321762733
# data num is :  500
# step 30001
# output index is :  7
# correct index is :  9
# corrent rs is :  0.058823529411764705
# mean loss is :  1.44121768450737
# mean reciprocal score is :  0.5855683005920357
# data num is :  500
# step 30501
# output index is :  1
# correct index is :  2
# corrent rs is :  0.72
# mean loss is :  1.4365288453102112
# mean reciprocal score is :  0.5874067477329805
# data num is :  500
# step 31001
# output index is :  16
# correct index is :  16
# corrent rs is :  1.0
# mean loss is :  1.4266042034626008
# mean reciprocal score is :  0.6000784672451281
# data num is :  500
# step 31501
# output index is :  4
# correct index is :  4
# corrent rs is :  1.0
# mean loss is :  1.4036330404281616
# mean reciprocal score is :  0.6225152507517753
# data num is :  500
# step 32001
# output index is :  6
# correct index is :  0
# corrent rs is :  0.8125
# mean loss is :  1.4092053792476653
# mean reciprocal score is :  0.616002161011988
# data num is :  500
# step 32501
# output index is :  5
# correct index is :  5
# corrent rs is :  1.0
# mean loss is :  1.361021167755127
# mean reciprocal score is :  0.6621536987115125
# data num is :  500
# step 33001
# output index is :  5
# correct index is :  13
# corrent rs is :  0.8
# mean loss is :  1.3605392787456512
# mean reciprocal score is :  0.6656569664361452
# data num is :  500
# step 33501
# output index is :  23
# correct index is :  3
# corrent rs is :  0.6
# mean loss is :  1.3524874333143235
# mean reciprocal score is :  0.6729739755418895
# data num is :  500
# step 34001
# output index is :  18
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3975055599212647
# mean reciprocal score is :  0.6278918954138543
# data num is :  500
# step 34501
# output index is :  6
# correct index is :  0
# corrent rs is :  0.2
# mean loss is :  1.373881427526474
# mean reciprocal score is :  0.6521130868838012
# data num is :  500
# step 35001
# output index is :  15
# correct index is :  9
# corrent rs is :  0.52
# mean loss is :  1.383584588766098
# mean reciprocal score is :  0.6421380692659521
# data num is :  500
# step 35501
# output index is :  19
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3531796556711198
# mean reciprocal score is :  0.6734482198583935
# data num is :  500
# step 36001
# output index is :  20
# correct index is :  9
# corrent rs is :  0.92
# mean loss is :  1.3461435241699218
# mean reciprocal score is :  0.6776457777220009
# data num is :  500
# step 36501
# output index is :  3
# correct index is :  6
# corrent rs is :  0.56
# mean loss is :  1.3501787704229355
# mean reciprocal score is :  0.672449965808485
# data num is :  500
# step 37001
# output index is :  20
# correct index is :  3
# corrent rs is :  0.68
# mean loss is :  1.3452078012228013
# mean reciprocal score is :  0.6784739089726773
# data num is :  500
# step 37501
# output index is :  12
# correct index is :  12
# corrent rs is :  1.0
# mean loss is :  1.368883723974228
# mean reciprocal score is :  0.658665019822985
# data num is :  500
# step 38001
# output index is :  3
# correct index is :  3
# corrent rs is :  1.0
# mean loss is :  1.3755939273834228
# mean reciprocal score is :  0.6501504758203015
# data num is :  500
# step 38501
# output index is :  4
# correct index is :  4
# corrent rs is :  1.0
# mean loss is :  1.3751905934810638
# mean reciprocal score is :  0.6500895307279432
# data num is :  500
# step 39001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3753574390411376
# mean reciprocal score is :  0.6486743411975312
# data num is :  500
# step 39501
# output index is :  7
# correct index is :  0
# corrent rs is :  0.88
# mean loss is :  1.3475914177894592
# mean reciprocal score is :  0.680113217735137
# data num is :  500
# step 40001
# output index is :  9
# correct index is :  2
# corrent rs is :  0.16
# mean loss is :  1.3736162583827973
# mean reciprocal score is :  0.6505588232026415
# data num is :  500
# step 40501
# output index is :  10
# correct index is :  0
# corrent rs is :  0.44
# mean loss is :  1.36471894967556
# mean reciprocal score is :  0.6593001841433417
# data num is :  500
# step 41001
# output index is :  3
# correct index is :  3
# corrent rs is :  1.0
# mean loss is :  1.365403925895691
# mean reciprocal score is :  0.6594230056388617
# data num is :  500
# step 41501
# output index is :  18
# correct index is :  3
# corrent rs is :  0.56
# mean loss is :  1.3483163216114045
# mean reciprocal score is :  0.6774100245172927
# data num is :  500
# step 42001
# output index is :  22
# correct index is :  7
# corrent rs is :  0.88
# mean loss is :  1.3638269052505494
# mean reciprocal score is :  0.6609963862894107
# data num is :  500
# step 42501
# output index is :  2
# correct index is :  1
# corrent rs is :  0.8
# mean loss is :  1.371325541138649
# mean reciprocal score is :  0.655884437505555
# data num is :  500
# step 43001
# output index is :  15
# correct index is :  8
# corrent rs is :  0.72
# mean loss is :  1.3577507145404815
# mean reciprocal score is :  0.6668866897547343
# data num is :  500
# step 43501
# output index is :  10
# correct index is :  0
# corrent rs is :  0.2
# mean loss is :  1.3676563522815703
# mean reciprocal score is :  0.6574445682223438
# data num is :  500
# step 44001
# output index is :  11
# correct index is :  0
# corrent rs is :  0.08
# mean loss is :  1.3539612786769868
# mean reciprocal score is :  0.6709628209523242
# data num is :  500
# step 44501
# output index is :  0
# correct index is :  6
# corrent rs is :  0.68
# mean loss is :  1.3299549984931947
# mean reciprocal score is :  0.6941234427612294
# data num is :  500
# step 45001
# output index is :  0
# correct index is :  1
# corrent rs is :  0.96
# mean loss is :  1.3383581714630126
# mean reciprocal score is :  0.6865482264140332
# data num is :  500
# step 45501
# output index is :  3
# correct index is :  6
# corrent rs is :  0.88
# mean loss is :  1.3585243554115296
# mean reciprocal score is :  0.6653823937008828
# data num is :  500
# step 46001
# output index is :  3
# correct index is :  2
# corrent rs is :  0.8333333333333334
# mean loss is :  1.3372873241901397
# mean reciprocal score is :  0.6868589635819227
# data num is :  500
# step 46501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3754863929748535
# mean reciprocal score is :  0.6484336447236074
# data num is :  500
# step 47001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3767862648963929
# mean reciprocal score is :  0.6464980993031437
# data num is :  500
# step 47501
# output index is :  6
# correct index is :  1
# corrent rs is :  0.9230769230769231
# mean loss is :  1.3401698276996612
# mean reciprocal score is :  0.683650538654223
# data num is :  500
# step 48001
# output index is :  17
# correct index is :  12
# corrent rs is :  0.44
# mean loss is :  1.3476386123895645
# mean reciprocal score is :  0.674661643528171
# data num is :  500
# step 48501
# output index is :  2
# correct index is :  3
# corrent rs is :  0.24
# mean loss is :  1.3434966751337052
# mean reciprocal score is :  0.680861278310836
# data num is :  500
# step 49001
# output index is :  9
# correct index is :  4
# corrent rs is :  0.2
# mean loss is :  1.3736239845752716
# mean reciprocal score is :  0.6503966424084584
# data num is :  500
# step 49501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3791262049674988
# mean reciprocal score is :  0.6471680143473432
# data num is :  500
# step 50001
# output index is :  22
# correct index is :  11
# corrent rs is :  0.92
# mean loss is :  1.3560359938144684
# mean reciprocal score is :  0.6682651354407549
# data num is :  500
# step 50501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3924674824476242
# mean reciprocal score is :  0.6317978632501047
# data num is :  500
# step 51001
# output index is :  11
# correct index is :  0
# corrent rs is :  0.92
# mean loss is :  1.3761723458766937
# mean reciprocal score is :  0.6459899414158776
# data num is :  500
# step 51501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3636605069637298
# mean reciprocal score is :  0.6596883412369923
# data num is :  500
# step 52001
# output index is :  3
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.3698090834617616
# mean reciprocal score is :  0.6522046265126418
# data num is :  500
# step 52501
# output index is :  0
# correct index is :  4
# corrent rs is :  0.72
# mean loss is :  1.3590217130184175
# mean reciprocal score is :  0.6665573084660512
# data num is :  500
# step 53001
# output index is :  11
# correct index is :  3
# corrent rs is :  0.2
# mean loss is :  1.3607820041179657
# mean reciprocal score is :  0.662487094418795
# data num is :  500
# step 53501
# output index is :  2
# correct index is :  18
# corrent rs is :  0.96
# mean loss is :  1.3571434724330902
# mean reciprocal score is :  0.6694608759257968
# data num is :  500
# step 54001
# output index is :  13
# correct index is :  8
# corrent rs is :  0.04
# mean loss is :  1.3694803516864777
# mean reciprocal score is :  0.6545359941557827
# data num is :  500
# step 54501
# output index is :  8
# correct index is :  3
# corrent rs is :  0.92
# mean loss is :  1.3365751779079438
# mean reciprocal score is :  0.6890442540800001
# data num is :  500
# step 55001
# output index is :  1
# correct index is :  1
# corrent rs is :  1.0
# mean loss is :  1.3538899459838867
# mean reciprocal score is :  0.6711108451567723
# data num is :  500
# step 55501
# output index is :  13
# correct index is :  12
# corrent rs is :  0.84
# mean loss is :  1.331855889081955
# mean reciprocal score is :  0.6914961540160381
# data num is :  500
# step 56001
# output index is :  17
# correct index is :  0
# corrent rs is :  0.56
# mean loss is :  1.348438916683197
# mean reciprocal score is :  0.6756340981542048
# data num is :  500
# step 56501
# output index is :  5
# correct index is :  5
# corrent rs is :  1.0
# mean loss is :  1.3415118398666381
# mean reciprocal score is :  0.6831608578434917
# data num is :  500
# step 57001
# output index is :  9
# correct index is :  5
# corrent rs is :  0.96
# mean loss is :  1.3583988394737243
# mean reciprocal score is :  0.6673723239938889
# data num is :  500
# step 57501
# output index is :  16
# correct index is :  1
# corrent rs is :  0.16666666666666666
# mean loss is :  1.3529775439500809
# mean reciprocal score is :  0.6723346417205075
# data num is :  500
# step 58001
# output index is :  6
# correct index is :  9
# corrent rs is :  0.44
# mean loss is :  1.366975026845932
# mean reciprocal score is :  0.658013333412597
# data num is :  500
# step 58501
# output index is :  3
# correct index is :  4
# corrent rs is :  0.36
# mean loss is :  1.3521087555885314
# mean reciprocal score is :  0.6719704500934958
# data num is :  500
# step 59001
# output index is :  3
# correct index is :  4
# corrent rs is :  0.42857142857142855
# mean loss is :  1.3513385564088822
# mean reciprocal score is :  0.6745821040324296
# data num is :  500
# step 59501
# output index is :  23
# correct index is :  21
# corrent rs is :  0.8
# mean loss is :  1.3826952550411225
# mean reciprocal score is :  0.6411350248282252
# data num is :  500
# step 60001
# output index is :  1
# correct index is :  2
# corrent rs is :  0.56
# mean loss is :  1.3493567366600037
# mean reciprocal score is :  0.6756396994561797
# data num is :  500
# step 60501
# output index is :  6
# correct index is :  0
# corrent rs is :  0.16
# mean loss is :  1.3730626544952393
# mean reciprocal score is :  0.650816928751017
# data num is :  500
# step 61001
# output index is :  8
# correct index is :  11
# corrent rs is :  0.96
# mean loss is :  1.3274865860939027
# mean reciprocal score is :  0.6978860798918997
# data num is :  500
# step 61501
# output index is :  24
# correct index is :  8
# corrent rs is :  0.96
# mean loss is :  1.3322216408252716
# mean reciprocal score is :  0.6929341003090627
# data num is :  500
# step 62001
# output index is :  12
# correct index is :  5
# corrent rs is :  0.2
# mean loss is :  1.3607043976783753
# mean reciprocal score is :  0.664354039760512
# data num is :  500
# step 62501
# output index is :  10
# correct index is :  2
# corrent rs is :  0.6923076923076923
# mean loss is :  1.3413372015953064
# mean reciprocal score is :  0.683742213010737
# data num is :  500
# step 63001
# output index is :  5
# correct index is :  2
# corrent rs is :  0.7272727272727273
# mean loss is :  1.3605677559375764
# mean reciprocal score is :  0.6640410906032833
# data num is :  500
# step 63501
# output index is :  0
# correct index is :  1
# corrent rs is :  0.5
# mean loss is :  1.3333354661464691
# mean reciprocal score is :  0.6907263384394582
# data num is :  500
# step 64001
# output index is :  3
# correct index is :  0
# corrent rs is :  0.84
# mean loss is :  1.352644764661789
# mean reciprocal score is :  0.6736714116198931
# data num is :  500
# step 64501
# output index is :  12
# correct index is :  20
# corrent rs is :  0.6
# mean loss is :  1.331448217868805
# mean reciprocal score is :  0.6913277859063057
# data num is :  500
# step 65001
# output index is :  20
# correct index is :  3
# corrent rs is :  0.56
# mean loss is :  1.3246971716880798
# mean reciprocal score is :  0.7006158917696477
# data num is :  500
# step 65501
# output index is :  3
# correct index is :  2
# corrent rs is :  0.84
# mean loss is :  1.3645638031959533
# mean reciprocal score is :  0.6618206144060839
# data num is :  500
# step 66001
# output index is :  4
# correct index is :  8
# corrent rs is :  0.52
# mean loss is :  1.355345380783081
# mean reciprocal score is :  0.6699667501084485
# data num is :  500
# step 66501
# output index is :  1
# correct index is :  11
# corrent rs is :  0.48
# mean loss is :  1.3369926126003266
# mean reciprocal score is :  0.6889339601188657
# data num is :  500
# step 67001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3462649168968202
# mean reciprocal score is :  0.6796423415231366
# data num is :  500
# step 67501
# output index is :  3
# correct index is :  9
# corrent rs is :  0.96
# mean loss is :  1.335738000869751
# mean reciprocal score is :  0.6887589912779369
# data num is :  500
# step 68001
# output index is :  13
# correct index is :  2
# corrent rs is :  0.04
# mean loss is :  1.3532335741519927
# mean reciprocal score is :  0.6707340758490699
# data num is :  500
# step 68501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3401483751535415
# mean reciprocal score is :  0.6841661233572064
# data num is :  500
# step 69001
# output index is :  11
# correct index is :  15
# corrent rs is :  0.17647058823529413
# mean loss is :  1.3590143327713013
# mean reciprocal score is :  0.6664404912201656
# data num is :  500
# step 69501
# output index is :  0
# correct index is :  8
# corrent rs is :  0.7333333333333333
# mean loss is :  1.3447500591278077
# mean reciprocal score is :  0.6792018097316002
# data num is :  500
# step 70001
# output index is :  2
# correct index is :  2
# corrent rs is :  1.0
# mean loss is :  1.319796053171158
# mean reciprocal score is :  0.7044557888881287
# data num is :  500
# step 70501
# output index is :  0
# correct index is :  21
# corrent rs is :  0.6
# mean loss is :  1.3185990815162658
# mean reciprocal score is :  0.7058256263012801
# data num is :  500
# step 71001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.88
# mean loss is :  1.3359124338626862
# mean reciprocal score is :  0.6905772635827997
# data num is :  500
# step 71501
# output index is :  15
# correct index is :  15
# corrent rs is :  1.0
# mean loss is :  1.3215902769565582
# mean reciprocal score is :  0.703223841336196
# data num is :  500
# step 72001
# output index is :  9
# correct index is :  0
# corrent rs is :  0.5294117647058824
# mean loss is :  1.3150981991291046
# mean reciprocal score is :  0.709969694966645
# data num is :  500
# step 72501
# output index is :  6
# correct index is :  0
# corrent rs is :  0.56
# mean loss is :  1.3498120896816255
# mean reciprocal score is :  0.6735858430827486
# data num is :  500
# step 73001
# output index is :  2
# correct index is :  0
# corrent rs is :  0.76
# mean loss is :  1.3339096415042877
# mean reciprocal score is :  0.6887361590883652
# data num is :  500
# step 73501
# output index is :  16
# correct index is :  17
# corrent rs is :  0.28
# mean loss is :  1.338055131673813
# mean reciprocal score is :  0.6884356226199282
# data num is :  500
# step 74001
# output index is :  3
# correct index is :  4
# corrent rs is :  0.46153846153846156
# mean loss is :  1.334810711145401
# mean reciprocal score is :  0.6887697324997434
# data num is :  500
# step 74501
# output index is :  19
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.3490476734638215
# mean reciprocal score is :  0.6757686519525848
# data num is :  500
# step 75001
# output index is :  21
# correct index is :  2
# corrent rs is :  0.72
# mean loss is :  1.3384393070936202
# mean reciprocal score is :  0.6856275190684039
# data num is :  500
# step 75501
# output index is :  1
# correct index is :  16
# corrent rs is :  0.96
# mean loss is :  1.3200475757122039
# mean reciprocal score is :  0.7050550477917555
# data num is :  500
# step 76001
# output index is :  21
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3268784625530243
# mean reciprocal score is :  0.6977100652843962
# data num is :  500
# step 76501
# output index is :  2
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.332215325832367
# mean reciprocal score is :  0.6911734304109164
# data num is :  500
# step 77001
# output index is :  2
# correct index is :  0
# corrent rs is :  0.48
# mean loss is :  1.3284141414165498
# mean reciprocal score is :  0.6969258621957904
# data num is :  500
# step 77501
# output index is :  2
# correct index is :  0
# corrent rs is :  0.3333333333333333
# mean loss is :  1.3253677895069123
# mean reciprocal score is :  0.697475059632265
# data num is :  500
# step 78001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3361683115959166
# mean reciprocal score is :  0.6884463667360442
# data num is :  500
# step 78501
# output index is :  10
# correct index is :  22
# corrent rs is :  0.96
# mean loss is :  1.3130131793022155
# mean reciprocal score is :  0.7111342212878279
# data num is :  500
# step 79001
# output index is :  12
# correct index is :  12
# corrent rs is :  1.0
# mean loss is :  1.3082961044311523
# mean reciprocal score is :  0.7160189016639867
# data num is :  500
# step 79501
# output index is :  4
# correct index is :  4
# corrent rs is :  1.0
# mean loss is :  1.3262455205917358
# mean reciprocal score is :  0.6964135261105238
# data num is :  500
# step 80001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3112399362325668
# mean reciprocal score is :  0.7144439811756417
# data num is :  500
# step 80501
# output index is :  10
# correct index is :  1
# corrent rs is :  0.76
# mean loss is :  1.3139213688373566
# mean reciprocal score is :  0.7102394398605533
# data num is :  500
# step 81001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.8125
# mean loss is :  1.342099734544754
# mean reciprocal score is :  0.6823110598454659
# data num is :  500
# step 81501
# output index is :  3
# correct index is :  3
# corrent rs is :  1.0
# mean loss is :  1.3347768890857696
# mean reciprocal score is :  0.6891844048393387
# data num is :  500
# step 82001
# output index is :  4
# correct index is :  0
# corrent rs is :  0.3333333333333333
# mean loss is :  1.3324010943174363
# mean reciprocal score is :  0.6921627803077398
# data num is :  500
# step 82501
# output index is :  23
# correct index is :  7
# corrent rs is :  0.72
# mean loss is :  1.326744899392128
# mean reciprocal score is :  0.6979119317835356
# data num is :  500
# step 83001
# output index is :  8
# correct index is :  0
# corrent rs is :  0.6
# mean loss is :  1.3062054386138917
# mean reciprocal score is :  0.719291648559708
# data num is :  500
# step 83501
# output index is :  3
# correct index is :  4
# corrent rs is :  0.16666666666666666
# mean loss is :  1.3210048079490662
# mean reciprocal score is :  0.703982342610351
# data num is :  500
# step 84001
# output index is :  0
# correct index is :  4
# corrent rs is :  0.08333333333333333
# mean loss is :  1.324933119058609
# mean reciprocal score is :  0.7002890919507349
# data num is :  500
# step 84501
# output index is :  8
# correct index is :  0
# corrent rs is :  0.76
# mean loss is :  1.3356767747402192
# mean reciprocal score is :  0.6883649575330065
# data num is :  500
# step 85001
# output index is :  0
# correct index is :  1
# corrent rs is :  0.6666666666666666
# mean loss is :  1.3213974990844726
# mean reciprocal score is :  0.7046741047251603
# data num is :  500
# step 85501
# output index is :  8
# correct index is :  9
# corrent rs is :  0.1875
# mean loss is :  1.3374662964344024
# mean reciprocal score is :  0.6866602778218918
# data num is :  500
# step 86001
# output index is :  5
# correct index is :  7
# corrent rs is :  0.5
# mean loss is :  1.3355025012493134
# mean reciprocal score is :  0.690619901737185
# data num is :  500
# step 86501
# output index is :  5
# correct index is :  5
# corrent rs is :  1.0
# mean loss is :  1.3463093242645263
# mean reciprocal score is :  0.6802945453445755
# data num is :  500
# step 87001
# output index is :  11
# correct index is :  3
# corrent rs is :  0.8
# mean loss is :  1.317561388015747
# mean reciprocal score is :  0.7063053656309893
# data num is :  500
# step 87501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3392738983631134
# mean reciprocal score is :  0.6863036933427468
# data num is :  500
# step 88001
# output index is :  1
# correct index is :  2
# corrent rs is :  0.96
# mean loss is :  1.3168301980495454
# mean reciprocal score is :  0.7067649860154652
# data num is :  500
# step 88501
# output index is :  6
# correct index is :  2
# corrent rs is :  0.28
# mean loss is :  1.3077799407243729
# mean reciprocal score is :  0.716313013873624
# data num is :  500
# step 89001
# output index is :  13
# correct index is :  0
# corrent rs is :  0.9375
# mean loss is :  1.3160666680336
# mean reciprocal score is :  0.7073166507159843
# data num is :  500
# step 89501
# output index is :  11
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.330932594537735
# mean reciprocal score is :  0.6940866673600998
# data num is :  500
# step 90001
# output index is :  16
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.3366990323066712
# mean reciprocal score is :  0.6893319106238128
# data num is :  500
# step 90501
# output index is :  13
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.3145246427059174
# mean reciprocal score is :  0.7092846079822419
# data num is :  500
# step 91001
# output index is :  3
# correct index is :  12
# corrent rs is :  0.64
# mean loss is :  1.336120414018631
# mean reciprocal score is :  0.6891586464507656
# data num is :  500
# step 91501
# output index is :  6
# correct index is :  7
# corrent rs is :  0.4666666666666667
# mean loss is :  1.3088821785449982
# mean reciprocal score is :  0.7157251141120431
# data num is :  500
# step 92001
# output index is :  6
# correct index is :  22
# corrent rs is :  0.4
# mean loss is :  1.3084183666706086
# mean reciprocal score is :  0.7158627345826875
# data num is :  500
# step 92501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3246665108203888
# mean reciprocal score is :  0.7001712218049961
# data num is :  500
# step 93001
# output index is :  1
# correct index is :  1
# corrent rs is :  1.0
# mean loss is :  1.3278746752738952
# mean reciprocal score is :  0.6953069318922349
# data num is :  500
# step 93501
# output index is :  20
# correct index is :  0
# corrent rs is :  0.48
# mean loss is :  1.3506992268562317
# mean reciprocal score is :  0.6736072805898432
# data num is :  500
# step 94001
# output index is :  5
# correct index is :  2
# corrent rs is :  0.52
# mean loss is :  1.3418251094818114
# mean reciprocal score is :  0.6843554218125244
# data num is :  500
# step 94501
# output index is :  6
# correct index is :  13
# corrent rs is :  0.88
# mean loss is :  1.3223556804656982
# mean reciprocal score is :  0.7034525697972778
# data num is :  500
# step 95001
# output index is :  9
# correct index is :  13
# corrent rs is :  0.6
# mean loss is :  1.3247239863872529
# mean reciprocal score is :  0.7017436163374473
# data num is :  500
# step 95501
# output index is :  4
# correct index is :  0
# corrent rs is :  0.7777777777777778
# mean loss is :  1.3299482774734497
# mean reciprocal score is :  0.6936137378281066
# data num is :  500
# step 96001
# output index is :  20
# correct index is :  3
# corrent rs is :  0.2
# mean loss is :  1.3331512577533722
# mean reciprocal score is :  0.6936500744162436
# data num is :  500
# step 96501
# output index is :  10
# correct index is :  0
# corrent rs is :  0.76
# mean loss is :  1.3310165812969208
# mean reciprocal score is :  0.6923438355706604
# data num is :  500
# step 97001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3398930299282075
# mean reciprocal score is :  0.6864444056314607
# data num is :  500
# step 97501
# output index is :  0
# correct index is :  9
# corrent rs is :  0.5416666666666666
# mean loss is :  1.3165380103588105
# mean reciprocal score is :  0.7093293217631738
# data num is :  500
# step 98001
# output index is :  6
# correct index is :  8
# corrent rs is :  0.68
# mean loss is :  1.3285353207588195
# mean reciprocal score is :  0.6972883530388035
# data num is :  500
# step 98501
# output index is :  22
# correct index is :  8
# corrent rs is :  0.9583333333333334
# mean loss is :  1.3471469597816468
# mean reciprocal score is :  0.6786370612471083
# data num is :  500
# step 99001
# output index is :  5
# correct index is :  19
# corrent rs is :  0.9
# mean loss is :  1.361909262418747
# mean reciprocal score is :  0.66275288731385
# data num is :  500
# step 99501
# output index is :  19
# correct index is :  2
# corrent rs is :  0.6
# mean loss is :  1.3517046525478362
# mean reciprocal score is :  0.6725948295295139
# data num is :  500
# step 100001
# output index is :  6
# correct index is :  9
# corrent rs is :  0.12
# mean loss is :  1.3701356630325316
# mean reciprocal score is :  0.6557308920545816
# data num is :  500
# step 100501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.28
# mean loss is :  1.3391972892284394
# mean reciprocal score is :  0.6860260018275491
# data num is :  500
# step 101001
# output index is :  9
# correct index is :  1
# corrent rs is :  0.96
# mean loss is :  1.3502406771183013
# mean reciprocal score is :  0.6748039424145791
# data num is :  500
# step 101501
# output index is :  10
# correct index is :  11
# corrent rs is :  0.96
# mean loss is :  1.3241214225292206
# mean reciprocal score is :  0.7012703409263297
# data num is :  500
# step 102001
# output index is :  6
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3115088608264922
# mean reciprocal score is :  0.7127157493669196
# data num is :  500
# step 102501
# output index is :  13
# correct index is :  13
# corrent rs is :  1.0
# mean loss is :  1.307580703496933
# mean reciprocal score is :  0.7166897276255396
# data num is :  500
# step 103001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.9
# mean loss is :  1.3497464392185212
# mean reciprocal score is :  0.6773035176041263
# data num is :  500
# step 103501
# output index is :  3
# correct index is :  10
# corrent rs is :  0.8333333333333334
# mean loss is :  1.3385453629493713
# mean reciprocal score is :  0.6871504593315781
# data num is :  500
# step 104001
# output index is :  1
# correct index is :  14
# corrent rs is :  0.1875
# mean loss is :  1.3127171639204025
# mean reciprocal score is :  0.7133064045672252
# data num is :  500
# step 104501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3472658667564392
# mean reciprocal score is :  0.6789631021719039
# data num is :  500
# step 105001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.321126029729843
# mean reciprocal score is :  0.7027815241610667
# data num is :  500
# step 105501
# output index is :  3
# correct index is :  6
# corrent rs is :  0.92
# mean loss is :  1.3202248106002807
# mean reciprocal score is :  0.7055398489712672
# data num is :  500
# step 106001
# output index is :  12
# correct index is :  15
# corrent rs is :  0.8
# mean loss is :  1.3468944368362428
# mean reciprocal score is :  0.679458835203473
# data num is :  500
# step 106501
# output index is :  3
# correct index is :  19
# corrent rs is :  0.96
# mean loss is :  1.3357681136131287
# mean reciprocal score is :  0.6886897193800205
# data num is :  500
# step 107001
# output index is :  4
# correct index is :  3
# corrent rs is :  0.96
# mean loss is :  1.3426885840892793
# mean reciprocal score is :  0.6834197573189283
# data num is :  500
# step 107501
# output index is :  3
# correct index is :  5
# corrent rs is :  0.7368421052631579
# mean loss is :  1.32615742790699
# mean reciprocal score is :  0.6979620500205433
# data num is :  500
# step 108001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.322029893875122
# mean reciprocal score is :  0.7022800752741067
# data num is :  500
# step 108501
# output index is :  2
# correct index is :  1
# corrent rs is :  0.24
# mean loss is :  1.342686818599701
# mean reciprocal score is :  0.6817593705058043
# data num is :  500
# step 109001
# output index is :  22
# correct index is :  0
# corrent rs is :  0.2
# mean loss is :  1.3094365692138672
# mean reciprocal score is :  0.7134014276848011
# data num is :  500
# step 109501
# output index is :  0
# correct index is :  11
# corrent rs is :  0.24
# mean loss is :  1.348531167268753
# mean reciprocal score is :  0.6762733575468667
# data num is :  500
# step 110001
# output index is :  2
# correct index is :  5
# corrent rs is :  0.7857142857142857
# mean loss is :  1.332495696783066
# mean reciprocal score is :  0.6900355572638119
# data num is :  500
# step 110501
# output index is :  1
# correct index is :  1
# corrent rs is :  1.0
# mean loss is :  1.3165367350578308
# mean reciprocal score is :  0.7084024310503512
# data num is :  500
# step 111001
# output index is :  9
# correct index is :  19
# corrent rs is :  0.64
# mean loss is :  1.3078991453647613
# mean reciprocal score is :  0.718696335972697
# data num is :  500
# step 111501
# output index is :  19
# correct index is :  0
# corrent rs is :  0.92
# mean loss is :  1.350037930727005
# mean reciprocal score is :  0.6743081549674808
# data num is :  500
# step 112001
# output index is :  2
# correct index is :  4
# corrent rs is :  0.8181818181818182
# mean loss is :  1.309595443725586
# mean reciprocal score is :  0.7144463338504874
# data num is :  500
# step 112501
# output index is :  6
# correct index is :  14
# corrent rs is :  0.96
# mean loss is :  1.3159080325365067
# mean reciprocal score is :  0.7094100426135681
# data num is :  500
# step 113001
# output index is :  0
# correct index is :  4
# corrent rs is :  0.04
# mean loss is :  1.3360862250328065
# mean reciprocal score is :  0.6887010442911058
# data num is :  500
# step 113501
# output index is :  3
# correct index is :  0
# corrent rs is :  0.32
# mean loss is :  1.3079021902084351
# mean reciprocal score is :  0.7162098170365845
# data num is :  500
# step 114001
# output index is :  22
# correct index is :  22
# corrent rs is :  1.0
# mean loss is :  1.3257965202331543
# mean reciprocal score is :  0.6998381600989765
# data num is :  500
# step 114501
# output index is :  0
# correct index is :  1
# corrent rs is :  0.52
# mean loss is :  1.3325114707946777
# mean reciprocal score is :  0.6930049570153595
# data num is :  500
# step 115001
# output index is :  8
# correct index is :  0
# corrent rs is :  0.4
# mean loss is :  1.3465942718982697
# mean reciprocal score is :  0.6798502152994244
# data num is :  500
# step 115501
# output index is :  1
# correct index is :  2
# corrent rs is :  0.8
# mean loss is :  1.3121578567028045
# mean reciprocal score is :  0.7124503056231692
# data num is :  500
# step 116001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3239792641401291
# mean reciprocal score is :  0.7011833290857743
# data num is :  500
# step 116501
# output index is :  13
# correct index is :  2
# corrent rs is :  0.08
# mean loss is :  1.3385033571720124
# mean reciprocal score is :  0.6851815997347498
# data num is :  500
# step 117001
# output index is :  8
# correct index is :  3
# corrent rs is :  0.18181818181818182
# mean loss is :  1.3410901800394057
# mean reciprocal score is :  0.6826332916930509
# data num is :  500
# step 117501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.875
# mean loss is :  1.3187425436973572
# mean reciprocal score is :  0.7056344929973181
# data num is :  500
# step 118001
# output index is :  8
# correct index is :  0
# corrent rs is :  0.88
# mean loss is :  1.315989503264427
# mean reciprocal score is :  0.7087830054679318
# data num is :  500
# step 118501
# output index is :  10
# correct index is :  2
# corrent rs is :  0.9333333333333333
# mean loss is :  1.325245943069458
# mean reciprocal score is :  0.6995636910638748
# data num is :  500
# step 119001
# output index is :  1
# correct index is :  12
# corrent rs is :  0.46153846153846156
# mean loss is :  1.3066131172180175
# mean reciprocal score is :  0.7177786872892891
# data num is :  500
# step 119501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.32
# mean loss is :  1.305147001504898
# mean reciprocal score is :  0.7186309542406408
# data num is :  500
# step 120001
# output index is :  9
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.3416237423419952
# mean reciprocal score is :  0.6816832036927033
# data num is :  500
# step 120501
# output index is :  20
# correct index is :  2
# corrent rs is :  0.36
# mean loss is :  1.3055621361732483
# mean reciprocal score is :  0.7208316207854749
# data num is :  500
# step 121001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3044575608968734
# mean reciprocal score is :  0.7211512434994742
# data num is :  500
# step 121501
# output index is :  4
# correct index is :  9
# corrent rs is :  0.12
# mean loss is :  1.327628958463669
# mean reciprocal score is :  0.6990526669287989
# data num is :  500
# step 122001
# output index is :  24
# correct index is :  0
# corrent rs is :  0.84
# mean loss is :  1.2960370173454285
# mean reciprocal score is :  0.7280107060441539
# data num is :  500
# step 122501
# output index is :  19
# correct index is :  0
# corrent rs is :  0.88
# mean loss is :  1.3198724126815795
# mean reciprocal score is :  0.7035283134496856
# data num is :  500
# step 123001
# output index is :  15
# correct index is :  11
# corrent rs is :  0.96
# mean loss is :  1.3065610740184783
# mean reciprocal score is :  0.7177848672014178
# data num is :  500
# step 123501
# output index is :  1
# correct index is :  4
# corrent rs is :  0.2857142857142857
# mean loss is :  1.3372327671051025
# mean reciprocal score is :  0.6909775043746724
# data num is :  500
# step 124001
# output index is :  3
# correct index is :  16
# corrent rs is :  0.92
# mean loss is :  1.3083690340518952
# mean reciprocal score is :  0.716698209789866
# data num is :  500
# step 124501
# output index is :  19
# correct index is :  21
# corrent rs is :  0.16
# mean loss is :  1.3129890563488007
# mean reciprocal score is :  0.7113341778891595
# data num is :  500
# step 125001
# output index is :  14
# correct index is :  2
# corrent rs is :  0.4
# mean loss is :  1.3329133615493773
# mean reciprocal score is :  0.6922238418536939
# data num is :  500
# step 125501
# output index is :  23
# correct index is :  9
# corrent rs is :  0.56
# mean loss is :  1.3259240908622743
# mean reciprocal score is :  0.7005246867457031
# data num is :  500
# step 126001
# output index is :  8
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.3171888399124145
# mean reciprocal score is :  0.7075076335294798
# data num is :  500
# step 126501
# output index is :  1
# correct index is :  10
# corrent rs is :  0.24
# mean loss is :  1.333445981502533
# mean reciprocal score is :  0.6913291673032851
# data num is :  500
# step 127001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3491439204216003
# mean reciprocal score is :  0.6751939283190299
# data num is :  500
# step 127501
# output index is :  4
# correct index is :  2
# corrent rs is :  0.2
# mean loss is :  1.3466753780841827
# mean reciprocal score is :  0.6787715297986292
# data num is :  500
# step 128001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3011371655464172
# mean reciprocal score is :  0.7227359115720124
# data num is :  500
# step 128501
# output index is :  24
# correct index is :  2
# corrent rs is :  0.68
# mean loss is :  1.3167036275863648
# mean reciprocal score is :  0.7071945232424207
# data num is :  500
# step 129001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3246227262020112
# mean reciprocal score is :  0.7009596866526183
# data num is :  500
# step 129501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3191563789844514
# mean reciprocal score is :  0.7040699155735752
# data num is :  500
# step 130001
# output index is :  0
# correct index is :  1
# corrent rs is :  0.92
# mean loss is :  1.3217361690998077
# mean reciprocal score is :  0.7040274627556082
# data num is :  500
# step 130501
# output index is :  5
# correct index is :  3
# corrent rs is :  0.44
# mean loss is :  1.3015565218925476
# mean reciprocal score is :  0.7240705402260642
# data num is :  500
# step 131001
# output index is :  1
# correct index is :  18
# corrent rs is :  0.28
# mean loss is :  1.2968653900623321
# mean reciprocal score is :  0.7274139185658423
# data num is :  500
# step 131501
# output index is :  12
# correct index is :  11
# corrent rs is :  0.56
# mean loss is :  1.317955966949463
# mean reciprocal score is :  0.7055220418914183
# data num is :  500
# step 132001
# output index is :  3
# correct index is :  4
# corrent rs is :  0.9583333333333334
# mean loss is :  1.3200206892490387
# mean reciprocal score is :  0.705946663279512
# data num is :  500
# step 132501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3361684954166413
# mean reciprocal score is :  0.6888280060368275
# data num is :  500
# step 133001
# output index is :  2
# correct index is :  3
# corrent rs is :  0.76
# mean loss is :  1.3262818892002106
# mean reciprocal score is :  0.7005611801450663
# data num is :  500
# step 133501
# output index is :  9
# correct index is :  12
# corrent rs is :  0.6
# mean loss is :  1.320692219734192
# mean reciprocal score is :  0.7048079918675416
# data num is :  500
# step 134001
# output index is :  6
# ...
# correct index is :  7
# corrent rs is :  0.625
# mean loss is :  1.311610318183899
# mean reciprocal score is :  0.7141603404430474
# data num is :  500
# step 772501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.2988730444908143
# mean reciprocal score is :  0.7280452670138369
# data num is :  500
# step 773001
# output index is :  1
# correct index is :  15
# corrent rs is :  0.16
# mean loss is :  1.3042701017856597
# mean reciprocal score is :  0.7206075006687418
# data num is :  500
# step 773501
# output index is :  1
# correct index is :  1
# corrent rs is :  1.0
# mean loss is :  1.2916734433174133
# mean reciprocal score is :  0.7323558333017689
# data num is :  500
# step 774001
# output index is :  5
# correct index is :  5
# corrent rs is :  1.0
# mean loss is :  1.2809835019111633
# mean reciprocal score is :  0.7441753187712807
# data num is :  500
# step 774501
# output index is :  15
# correct index is :  5
# corrent rs is :  0.8
# mean loss is :  1.2958304107189178
# mean reciprocal score is :  0.7303357900470627
# data num is :  500
# step 775001
# output index is :  21
# correct index is :  21
# corrent rs is :  1.0
# mean loss is :  1.3236532847881317
# mean reciprocal score is :  0.7015210923041453
# data num is :  500
# step 775501
# output index is :  2
# correct index is :  0
# corrent rs is :  0.72
# mean loss is :  1.3244008674621581
# mean reciprocal score is :  0.6991890492780721
# data num is :  500
# step 776001
# output index is :  5
# correct index is :  17
# corrent rs is :  0.96
# mean loss is :  1.3071423835754394
# mean reciprocal score is :  0.7206090934975498
# data num is :  500
# step 776501
# output index is :  16
# correct index is :  16
# corrent rs is :  1.0
# mean loss is :  1.2799538066387177
# mean reciprocal score is :  0.7436707376688761
# data num is :  500
# step 777001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.5
# mean loss is :  1.3276735842227936
# mean reciprocal score is :  0.6976089125480185
# data num is :  500
# step 777501
# output index is :  5
# correct index is :  0
# corrent rs is :  0.68
# mean loss is :  1.288091630935669
# mean reciprocal score is :  0.7377446881764974
# data num is :  500
# step 778001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3000176842212676
# mean reciprocal score is :  0.7252515678104512
# data num is :  500
# step 778501
# output index is :  4
# correct index is :  0
# corrent rs is :  0.92
# mean loss is :  1.285237173318863
# mean reciprocal score is :  0.7401677512923208
# data num is :  500
# step 779001
# output index is :  23
# correct index is :  12
# corrent rs is :  0.8
# mean loss is :  1.299888308763504
# mean reciprocal score is :  0.7254919612655785
# data num is :  500
# step 779501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.2930672693252563
# mean reciprocal score is :  0.7328340441684666
# data num is :  500
# step 780001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.88
# mean loss is :  1.2905814459323883
# mean reciprocal score is :  0.7372101116686667
# data num is :  500
# step 780501
# output index is :  17
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.3091093049049378
# mean reciprocal score is :  0.7170111437889813
# data num is :  500
# step 781001
# output index is :  15
# correct index is :  13
# corrent rs is :  0.92
# mean loss is :  1.30203626537323
# mean reciprocal score is :  0.7235304863451414
# data num is :  500
# step 781501
# output index is :  15
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.3032794177532196
# mean reciprocal score is :  0.7224789913140209
# data num is :  500
# step 782001
# output index is :  2
# correct index is :  24
# corrent rs is :  0.32
# mean loss is :  1.2850179188251496
# mean reciprocal score is :  0.7400632798420819
# data num is :  500
# step 782501
# output index is :  10
# correct index is :  0
# corrent rs is :  0.24
# mean loss is :  1.2759763391017913
# mean reciprocal score is :  0.7501518202827371
# data num is :  500
# step 783001
# output index is :  9
# correct index is :  0
# corrent rs is :  0.64
# mean loss is :  1.3163082466125489
# mean reciprocal score is :  0.7081860171367198
# data num is :  500
# step 783501
# output index is :  4
# correct index is :  13
# corrent rs is :  0.72
# mean loss is :  1.3131269023418426
# mean reciprocal score is :  0.7106499122257917
# data num is :  500
# step 784001
# output index is :  20
# correct index is :  20
# corrent rs is :  1.0
# mean loss is :  1.3007279360294342
# mean reciprocal score is :  0.7261523137296285
# data num is :  500
# step 784501
# output index is :  14
# correct index is :  0
# corrent rs is :  0.36
# mean loss is :  1.3043067290782928
# mean reciprocal score is :  0.7215688566598593
# data num is :  500
# step 785001
# output index is :  23
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.2939137003421783
# mean reciprocal score is :  0.7311808705999884
# data num is :  500
# step 785501
# output index is :  8
# correct index is :  2
# corrent rs is :  0.16
# mean loss is :  1.3135016996860505
# mean reciprocal score is :  0.7113874885548781
# data num is :  500
# step 786001
# output index is :  4
# correct index is :  15
# corrent rs is :  0.32
# mean loss is :  1.2965919387340545
# mean reciprocal score is :  0.7273050379415231
# data num is :  500
# step 786501
# output index is :  2
# correct index is :  4
# corrent rs is :  0.8
# mean loss is :  1.3095156967639923
# mean reciprocal score is :  0.7170194871073947
# data num is :  500
# step 787001
# output index is :  9
# correct index is :  9
# corrent rs is :  1.0
# mean loss is :  1.3183790364265442
# mean reciprocal score is :  0.7061489663035841
# data num is :  500
# step 787501
# output index is :  6
# correct index is :  3
# corrent rs is :  0.64
# mean loss is :  1.2987271156311035
# mean reciprocal score is :  0.7254131562967477
# data num is :  500
# step 788001
# output index is :  6
# correct index is :  0
# corrent rs is :  0.125
# mean loss is :  1.2961760988235473
# mean reciprocal score is :  0.7294465928516674
# data num is :  500
# step 788501
# output index is :  4
# correct index is :  4
# corrent rs is :  1.0
# mean loss is :  1.2965394132137298
# mean reciprocal score is :  0.72818155811449
# data num is :  500
# step 789001
# output index is :  1
# correct index is :  2
# corrent rs is :  0.96
# mean loss is :  1.2887958841323852
# mean reciprocal score is :  0.7370287161436396
# data num is :  500
# step 789501
# output index is :  16
# correct index is :  5
# corrent rs is :  0.4
# mean loss is :  1.2901721584796906
# mean reciprocal score is :  0.7340134721241127
# data num is :  500
# step 790001
# output index is :  4
# correct index is :  23
# corrent rs is :  0.24
# mean loss is :  1.3126782579421996
# mean reciprocal score is :  0.712375452405165
# data num is :  500
# step 790501
# output index is :  10
# correct index is :  11
# corrent rs is :  0.52
# mean loss is :  1.295447942495346
# mean reciprocal score is :  0.7307370822471075
# data num is :  500
# step 791001
# output index is :  6
# correct index is :  3
# corrent rs is :  0.375
# mean loss is :  1.3151350567340852
# mean reciprocal score is :  0.7100575904959072
# data num is :  500
# step 791501
# output index is :  11
# correct index is :  11
# corrent rs is :  1.0
# mean loss is :  1.3028697247505188
# mean reciprocal score is :  0.7232646327429317
# data num is :  500
# step 792001
# output index is :  3
# correct index is :  6
# corrent rs is :  0.14285714285714285
# mean loss is :  1.2999648711681366
# mean reciprocal score is :  0.7239966724144976
# data num is :  500
# step 792501
# output index is :  18
# correct index is :  0
# corrent rs is :  0.16
# mean loss is :  1.32784557557106
# mean reciprocal score is :  0.697325788669386
# data num is :  500
# step 793001
# output index is :  14
# correct index is :  14
# corrent rs is :  1.0
# mean loss is :  1.3075380969047545
# mean reciprocal score is :  0.7183225654013499
# data num is :  500
# step 793501
# output index is :  4
# correct index is :  1
# corrent rs is :  0.52
# mean loss is :  1.3309518365859985
# mean reciprocal score is :  0.6952339937113033
# data num is :  500
# step 794001
# output index is :  5
# correct index is :  0
# corrent rs is :  0.5384615384615384
# mean loss is :  1.3139157724380492
# mean reciprocal score is :  0.7115432078641362
# data num is :  500
# step 794501
# output index is :  0
# correct index is :  4
# corrent rs is :  0.96
# mean loss is :  1.3182037501335144
# mean reciprocal score is :  0.7071383629950462
# data num is :  500
# step 795001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.96
# mean loss is :  1.29360667347908
# mean reciprocal score is :  0.7292449625013414
# data num is :  500
# step 795501
# output index is :  2
# correct index is :  1
# corrent rs is :  0.5833333333333334
# mean loss is :  1.3319448969364167
# mean reciprocal score is :  0.6947091333623369
# data num is :  500
# step 796001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.308534815788269
# mean reciprocal score is :  0.7177871194691247
# data num is :  500
# step 796501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.9285714285714286
# mean loss is :  1.286466742515564
# mean reciprocal score is :  0.7383809681023566
# data num is :  500
# step 797001
# output index is :  1
# correct index is :  0
# corrent rs is :  0.3333333333333333
# mean loss is :  1.2942626657485963
# mean reciprocal score is :  0.7317435203358728
# data num is :  500
# step 797501
# output index is :  11
# correct index is :  2
# corrent rs is :  0.96
# mean loss is :  1.3091658825874328
# mean reciprocal score is :  0.7165982003296052
# data num is :  500
# step 798001
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.3172525548934937
# mean reciprocal score is :  0.7071653564105386
# data num is :  500
# step 798501
# output index is :  14
# correct index is :  0
# corrent rs is :  0.16
# mean loss is :  1.3219301912784576
# mean reciprocal score is :  0.7043151989162626
# data num is :  500
# step 799001
# output index is :  3
# correct index is :  5
# corrent rs is :  0.5833333333333334
# mean loss is :  1.3127448003292084
# mean reciprocal score is :  0.7126326896720934
# data num is :  500
# step 799501
# output index is :  1
# correct index is :  3
# corrent rs is :  0.9583333333333334
# mean loss is :  1.2849751839637755
# mean reciprocal score is :  0.7414376545266391
# data num is :  500
# step 800001
# output index is :  4
# correct index is :  4
# corrent rs is :  1.0
# mean loss is :  1.3340957310199737
# mean reciprocal score is :  0.6912410959311096
# data num is :  500
# step 800501
# output index is :  1
# correct index is :  0
# corrent rs is :  0.36
# mean loss is :  1.3179260563850403
# mean reciprocal score is :  0.7077355170285511
# data num is :  500
# step 801001
# output index is :  4
# correct index is :  5
# corrent rs is :  0.7894736842105263
# mean loss is :  1.303232223510742
# mean reciprocal score is :  0.7221209661846205
# data num is :  500
# step 801501
# output index is :  8
# correct index is :  8
# corrent rs is :  1.0
# mean loss is :  1.314333087682724
# mean reciprocal score is :  0.7103947687601277
# data num is :  500
# step 802001
# output index is :  15
# correct index is :  9
# corrent rs is :  0.8
# mean loss is :  1.3174091551303864
# mean reciprocal score is :  0.7081326900826846
# data num is :  500
# step 802501
# output index is :  5
# correct index is :  8
# corrent rs is :  0.92
# mean loss is :  1.3194648516178131
# mean reciprocal score is :  0.7048765345721266
# data num is :  500
# step 803001
# output index is :  9
# correct index is :  0
# corrent rs is :  0.3333333333333333
# mean loss is :  1.3037413547039032
# mean reciprocal score is :  0.7209125222493666
# data num is :  500
# step 803501
# output index is :  18
# correct index is :  18
# corrent rs is :  1.0
# mean loss is :  1.3133808302879333
# mean reciprocal score is :  0.712463999256453
# data num is :  500
# step 804001
# output index is :  14
# correct index is :  13
# corrent rs is :  0.75
# mean loss is :  1.2848444018363954
# mean reciprocal score is :  0.7401463553588689
# data num is :  500
# step 804501
# output index is :  6
# correct index is :  2
# corrent rs is :  0.2857142857142857
# mean loss is :  1.3416825108528136
# mean reciprocal score is :  0.6829220705000573
# data num is :  500
# step 805001
# output index is :  12
# correct index is :  0
# corrent rs is :  0.8
# mean loss is :  1.3121414704322816
# mean reciprocal score is :  0.713564317995087
# data num is :  500
# step 805501
# output index is :  2
# correct index is :  5
# corrent rs is :  0.16666666666666666
# mean loss is :  1.3309046308994292
# mean reciprocal score is :  0.6953573270046687
# data num is :  500
# step 806001
# output index is :  2
# correct index is :  0
# corrent rs is :  0.76
# mean loss is :  1.3230509252548217
# mean reciprocal score is :  0.7008834655870744
# data num is :  500
# step 806501
# output index is :  22
# correct index is :  0
# corrent rs is :  0.4
# mean loss is :  1.320035526752472
# mean reciprocal score is :  0.7061888059093202
# data num is :  500
# step 807001
# output index is :  5
# correct index is :  5
# corrent rs is :  1.0
# mean loss is :  1.2951365885734558
# mean reciprocal score is :  0.7288890084943846
# data num is :  500
# step 807501
# output index is :  0
# correct index is :  3
# corrent rs is :  0.88
# mean loss is :  1.3235207405090332
# mean reciprocal score is :  0.7016339121907684
# data num is :  500
# step 808001
# output index is :  22
# correct index is :  3
# corrent rs is :  0.88
# mean loss is :  1.3152447726726533
# mean reciprocal score is :  0.7101228018793992
# data num is :  500
# step 808501
# output index is :  3
# correct index is :  0
# corrent rs is :  0.92
# mean loss is :  1.3268292145729066
# mean reciprocal score is :  0.6976469761031205
# data num is :  500
# step 809001
# output index is :  6
# correct index is :  2
# corrent rs is :  0.6
# mean loss is :  1.3161690118312837
# mean reciprocal score is :  0.7101439910198237
# data num is :  500
# step 809501
# output index is :  7
# correct index is :  9
# corrent rs is :  0.8
# mean loss is :  1.3034239120483397
# mean reciprocal score is :  0.7217141445289875
# data num is :  500
# step 810001
# output index is :  8
# correct index is :  7
# corrent rs is :  0.92
# mean loss is :  1.3057288503646851
# mean reciprocal score is :  0.719177317150401
# data num is :  500
# step 810501
# output index is :  1
# correct index is :  3
# corrent rs is :  0.48
# mean loss is :  1.3162868008613586
# mean reciprocal score is :  0.7086991385034701
# data num is :  500
# step 811001
# output index is :  6
# correct index is :  0
# corrent rs is :  0.2
# mean loss is :  1.2979388082027434
# mean reciprocal score is :  0.7258847614801992
# data num is :  500
# step 811501
# output index is :  5
# correct index is :  3
# corrent rs is :  0.96
# mean loss is :  1.3146130385398864
# mean reciprocal score is :  0.7114601164869135
# data num is :  500
# step 812001
# output index is :  7
# correct index is :  9
# corrent rs is :  0.2727272727272727
# mean loss is :  1.2783281581401824
# mean reciprocal score is :  0.7475914787178837
# data num is :  500
# step 812501
# output index is :  0
# correct index is :  1
# corrent rs is :  0.92
# mean loss is :  1.2992416257858277
# mean reciprocal score is :  0.7266408251983422
# data num is :  500
# step 813001
# output index is :  12
# correct index is :  12
# corrent rs is :  1.0
# mean loss is :  1.3017105700969696
# mean reciprocal score is :  0.7227023432045738
# data num is :  500
# step 813501
# output index is :  0
# correct index is :  10
# corrent rs is :  0.9583333333333334
# mean loss is :  1.2758167111873626
# mean reciprocal score is :  0.749270272350927
# data num is :  500
# step 814001
# output index is :  2
# correct index is :  4
# corrent rs is :  0.52
# mean loss is :  1.2963651518821717
# mean reciprocal score is :  0.7296595983240817
# data num is :  500
# step 814501
# output index is :  0
# correct index is :  0
# corrent rs is :  1.0
# mean loss is :  1.290132801055908
# mean reciprocal score is :  0.7354370137724857
# data num is :  500
# step 815001
# output index is :  1
# correct index is :  1
# corrent rs is :  1.0
# mean loss is :  1.3002127194404602
# mean reciprocal score is :  0.7235712220094696
# data num is :  500
# step 815501
# output index is :  3
# correct index is :  0
# corrent rs is :  0.8
# mean loss is :  1.33552845287323
# mean reciprocal score is :  0.6887227846858129
# data num is :  500
# step 816001
# output index is :  2
# correct index is :  0
# corrent rs is :  0.9583333333333334
# mean loss is :  1.3154220774173737
# mean reciprocal score is :  0.7084480779202699
# data num is :  500

# %%
True ==1
# Out:
# True
